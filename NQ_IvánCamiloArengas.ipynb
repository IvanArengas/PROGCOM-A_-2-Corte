# %% [markdown]
# ##Laboratorio de Mecanica
# # Laboratorio de Ecuaciones Empiricas Ivan Arengas

# %% [markdown]
# ##**Resumen**

# %% [markdown]
# En el posterior informe de laboratorio se contrasta la ecuación teórica del
# periodo de un péndulo con una ecuación obtenida anteriormente mediante
# experimentos tras analizar el comportamiento de oscilación de 6 anillos de
# diferentes medidas y pesos, por consiguiente, se midieron sus diámetros tanto
# el interno y externo, masas y periodos de oscilación gracias a herramientas
# como un flexómetro, balanza, calibrador, sensores infrarrojos y apoyándonos
# de CASSY LAB finalmente. Los resultados apuntan a una relación
# directamente proporcional del periodo con el diámetro medio y la masa,
# considerando que entre mayor sea el peso y diámetro medio del anillo,
# superior será su período. Asimismo, se expresa una alteración en la oscilación
# del anillo 6, que fue causada por error del bienintencionado, que genera un
# gran cambio en la ecuación experimental obtenida.
#
# Tenemos la siguiente ecuación relevante:
# •	Ecuación teórica:
#
#
#
# 𝑇 = 2𝜋√ 𝐷𝐺   [1]
#
#
#
# En esta ecuación, T es el periodo, π es una constante matemática aproximadamente 3.1415 y g la constante de gravedad universal que aproximadamente es 9,805 m/s^2.

# %% [markdown]
# ##**Introducción**

# %% [markdown]
# La física es una ciencia natural que estudia como opera el universo y busca
# describir como funcionan las cosas a nuestro alrededor. Se divide en teórica y
# experimental, a través de la zona experimental es posible proporcionar
# información mediante la observación de los fenómenos físicos y los
# experimentos. En la realización de estos ejercicios en la mayoría de las
# ocasiones se extraen los dos tipos de variables [independientes y/o
# dependientes] que deben ser asignadas para generar una ecuación empírica
# que es obtenida a partir de un conjunto de valores experimentales de dos
# variables. La relación matemática entre las dos variables se expresa mediante
# una función matemática donde “y” es la variable dependiente y “x” es la
# variable independiente.
# El propósito de este laboratorio es averiguar la relación entre la Masa y la
# dimensión del periodo de oscilación de cualquier anillo, y comparar los
# resultados logrados con la ecuación teórica para el periodo de oscilación de un
# anillo oscilante, no olvidándonos que el periodo de un anillo oscilante y la
# masa sean proporcionalmente directos.

# %% [markdown]
# #**Desarrollo Experimental**

# %% [markdown]
# En el desarrollo de este laboratorio se implementaron una variedad de
# materiales y equipos que los conoceremos a continuación:![DEXP.jpg](data:image/jpeg;base64,...)
#
# Materiales y equipos utilizados
# 1.	Módulo de adquisición de datos CASSY LAB
# 2.	Sensor infrarrojo tipo horquilla
# 3.	Set de 6 anillos oscilantes
# 4.	Flexómetro
# 5.	Calibrador o vernier
# 6.	Balanza
# 7.	Soporte metálico,
# 8.	Base de hierro
# 9.	Varilla de 1 metro de longitud
# 10.	Nueces de sujeción (2)
# 11.	Varillas cortas de 30 cm de longitud, de diferente diámetro para anillos.
#
#
# Se comenzó realizando las mediciones al anillo asignado por el profesor que
# fueron: masa, diámetro interno y externo utilizando la balanza, calibrador y
# flexómetro. Después, se escogió una de las varillas cortas para poder
# introducir el anillo, que era el más pequeño mediante CASSY LAB se logró
# obtener el periodo de oscilación del anillo desde que fue soltado y se repitió
# tres veces para encontrar una mejor exactitud de los valores tomados.
# Al tener los datos tomados, procedemos a graficar para verlos de otra manera.
#
# ![PESO.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Resultados y Discusión**
#
# Los resultados de las mediciones de la sexta de anillos fueron los siguientes:
#
# ![Ixd.png](data:image/png;base64,...)
#
# ![Ixd2.png](data:image/png;base64,...)
#
# ![Ixd3.png](data:image/png;base64,...)
#
# Después de analizar estas graficas nos podemos dar cuenta que el periodo de oscilación es directamente proporcional a la masa y al diámetro medio, ya que si aumenta la masa aumenta el periodo de oscilación y si aumenta el diámetro medio, aumenta el periodo de oscilación.
# Posteriormente compararemos la ecuación experimental con la ecuación [1], necesariamente se calculo el valor de la gravedad igualando ambas formulas
#
# 0.5
# 𝑇 = 2𝜋√DG    ≡ 2𝜋 √𝐷/√G = 	 1.4806𝐷*0.6495 ≈ 1.4806𝐷*0.5	[2]
#
#
#
# Mediante un despeje podemos determinar que:
# 𝐺 = 18.008	[3]
#
#
# Como podemos apreciar el resultado de la gravedad es casi el doble de lo que es la constante gravitacional universal (9.806). Para solucionarlo decidimos no redondearlo y realizarlo con el exponente adecuado. La ecuación queda de la siguiente manera:
#
# 𝑇 = 2𝜋√𝐷𝐺
#
# ≡ 2𝜋√𝐷√𝐺
#
# = 2𝜋𝐷*0.6495/𝐺*0.6495 = 1.4806𝐷*0.6495
#
# 2𝜋𝐷*0.6495/ 𝐷*0.6495 = 1.4806𝐷*0.6495
#
# 2𝜋/𝐺0.6495 =1/1.4806
#
# G*0.6495 ≈ 𝐺1/1.5396 =2𝜋/1.4806
#
# 𝐺 = (2𝜋/1.4806) 1.5396 =2*1.5396𝜋*1.5396/1.48061.5396
#
# 𝐺 ≈ 9.257
#
# Podemos ver que mediante esta forma da un valor mas cercano a la constante
# gravitacional universal, la diferencia que se da es por los exponentes que
# puede ser un error de calculo humano que siempre puede ocurrir o algún fallo
# no tan probable de alguna maquina o equipos.
# También nos damos cuenta de lo que un error puede afectar tanto a una
# respuesta u otra, por mal manejos de equipos por parte del humano, o por
# fallos irrelevantes de medición que hacen demasiado la diferencia.

# %% [markdown]
# #**Conclusiones**

# %% [markdown]
# ❖Tras el análisis podemos deducir que hemos identificado que tipo de
# proporcionalidad tenían cada una de nuestras variables como (Período,
# Masa y Diámetro medio) y entender por qué son directamente
# proporcionales.
#
#
# ❖ El redondeo y las cifras significativas son métodos muy funcionales,
# pero debemos saber manejarlos ya que un pequeño error de ese uso
# puede generar un cambio en los decimales que pueda afectar a un
# resultado con menos exactitud.
#
#
# ❖ El error de medición humano no solamente puede afectar en un
# resultado de alguna ecuación, despejes de esta, también puede afectar en
# la interpretación, en el desarrollo de laboratorio, practico, teórico y
# experimental, evitar ese tipo de desigualdades por una mala acción
# dentro o fuera del laboratorio.
#
#
# ❖ Gracias a todo lo anterior de este informe, podemos interpretar que
# debemos realizar muy bien cada zona de un laboratorio (experimental y
# practica) y la parte teórica e interpretativa de cualquier experimento.
